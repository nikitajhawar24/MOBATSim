# %%
import numpy as np
data = np.genfromtxt("Urbancitytraffic_v6.csv", delimiter=",", names=["Time", "Speed"])
data
import matplotlib.pyplot as plt

plt.plot(data['Time'], data['Speed'], label='Speed')
plt.xlabel('Time')
plt.ylabel('Speed')
plt.title('Vehicle 6')
plt.grid(True)
plt.show()
