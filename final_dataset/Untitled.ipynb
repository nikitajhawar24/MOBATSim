# %%
import numpy as np
data = np.genfromtxt("Urbancitytraffic_random_v2.csv", delimiter=",", names=["Time", "Speed"])
data
import matplotlib.pyplot as plt

#plt.figure(figsize=(15, 7))
plt.plot(data['Time'], data['Speed'], label='Speed')
plt.xlabel('Time')
plt.ylabel('Speed')
plt.title('Vehicle 6')
plt.grid(True)
#plt.ylim([0,14])
plt.show()
