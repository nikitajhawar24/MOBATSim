# %%
import pandas as pd
import os
import glob
  
  
# use glob to get all the csv files 
# in the folder
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
  
  
# loop over the list of csv files
for f in csv_files:
      
    # read the csv file
    df = pd.read_csv(f)
    df.columns = ['Time','Speed','Rotation','Position','Translation']
    df.to_csv(f,index=False)
    display(df)
    print(f)
# Out:
#            Time     Speed  Rotation    Position  Translation
# 0      0.020005   0.00003  1.570796 -199.999999  -300.000000
# 1      0.040010   0.12006  1.570796 -199.997598  -300.000000
# 2      0.060015   0.24009  1.570796 -199.992795  -300.000000
# 3      0.080020   0.36012  1.570796 -199.985590  -300.000000
# 4      0.100025   0.48015  1.570796 -199.975985  -300.000000
# ...         ...       ...       ...         ...          ...
# 3994  79.919980  13.00000 -1.139128  339.398349   245.155564
# 3995  79.939985  13.00000 -1.144074  339.161872   245.263787
# 3996  79.959990  13.00000 -1.149020  338.924862   245.370839
# 3997  79.979995  13.00000 -1.153966  338.687326   245.476718
# 3998  80.000000  13.00000 -1.158912  338.449270   245.581421
#
# [3999 rows x 5 columns]
# C:\Users\INT004435\OneDrive - TeamViewer\Documents\GitHub\MOBATSim\Datasets_for_label_DL_model\Multivariate\StuckAt\CSV files\Platoon Controlfault_StuckAt_10_V2.csv
# ...

# %%
import pandas as pd  

df_source1 = pd.read_csv('sample_StuckAt_10_V6.csv') 
df_source2 = pd.read_csv('Platoon Controlfault_StuckAt_10_V6.csv') 
df_source3 = pd.read_csv('Road Merge Collisionfault_StuckAt_10_V6.csv')
df_source4 = pd.read_csv('Urban City Trafficfault_StuckAt_10_V6.csv')

df_source2["Label"]=df_source1["Label"]
df_source3["Label"]=df_source1["Label"]
df_source4["Label"]=df_source1["Label"]


df_source2.to_csv('Platoon Controlfault_StuckAt_10_V6.csv',index=False) 
df_source3.to_csv('Road Merge Collisionfault_StuckAt_10_V6.csv',index=False) 
df_source4.to_csv('Urban City Trafficfault_StuckAt_10_V6.csv',index=False)

# %%
import pandas as pd
import glob
import os
 
path = os.getcwd()    
# merging the files
files = os.path.join(path,"*.csv")
  
# A list of all joined files is returned
files = glob.glob(files)
  
# Finally, the files are joined
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df.to_csv('StuckAt_Data.csv', index=False)
print(df)
# Out:
#              Time     Speed  Rotation    Position  Translation  Label
# 0        0.020005  0.000030  3.141593  170.000000  -230.000001      0
# 1        0.040010  0.120060  3.141593  170.000000  -230.002402      0
# 2        0.060015  0.240090  3.141593  170.000000  -230.007205      0
# 3        0.080020  0.360120  3.141593  170.000000  -230.014410      0
# 4        0.100025  0.480150  3.141593  170.000000  -230.024015      0
# ...           ...       ...       ...         ...          ...    ...
# 119965  79.919980  9.918843  1.570796  145.766292  -100.000000      0
# 119966  79.939985  9.920500  1.570796  145.964752  -100.000000      0
# 119967  79.959990  9.922124  1.570796  146.163244  -100.000000      0
# 119968  79.979995  9.923714  1.570796  146.361768  -100.000000      0
# 119969  80.000000  9.925272  1.570796  146.560323  -100.000000      0
#
# [119970 rows x 6 columns]
