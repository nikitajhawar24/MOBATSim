# %%
import pandas as pd
import os
import glob
  
  
# use glob to get all the csv files 
# in the folder
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
  
  
# loop over the list of csv files
for f in csv_files:
      
    # read the csv file
    df = pd.read_csv(f)
    df.columns = ['Time','Speed','Rotation','Position','Translation']
    df.to_csv(f,index=False)
    display(df)
    print(f)
# Out:
#            Time      Speed      Rotation    Position  Translation
# 0      0.020005   0.000030  1.570796e+00 -199.999999  -300.000000
# 1      0.040010   0.120060  1.570796e+00 -199.997598  -300.000000
# 2      0.060015   0.240090  1.570796e+00 -199.992795  -300.000000
# 3      0.080020   0.360120  1.570796e+00 -199.985590  -300.000000
# 4      0.100025   0.480150  1.570796e+00 -199.975985  -300.000000
# ...         ...        ...           ...         ...          ...
# 3994  79.919980  12.999188  2.360334e-13  370.000000   117.558970
# 3995  79.939985  12.999205  2.360334e-13  370.000000   117.819019
# 3996  79.959990  12.999221  2.360334e-13  370.000000   118.079068
# 3997  79.979995  12.999237  2.360334e-13  370.000000   118.339118
# 3998  80.000000  12.999253  2.360334e-13  370.000000   118.599168
#
# [3999 rows x 5 columns]
# ...

# %%
import pandas as pd  

df_source1 = pd.read_csv('sample_3_V6.csv') 
df_source2 = pd.read_csv('Platoon Controlfault_Offset_3_V6.csv') 
df_source3 = pd.read_csv('Road Merge Collisionfault_Offset_3_V6.csv')
df_source4 = pd.read_csv('Urban City Trafficfault_Offset_3_V6.csv')

df_source2["Label"]=df_source1["Label"]
df_source3["Label"]=df_source1["Label"]
df_source4["Label"]=df_source1["Label"]


df_source2.to_csv('Platoon Controlfault_Offset_3_V6.csv',index=False) 
df_source3.to_csv('Road Merge Collisionfault_Offset_3_V6.csv',index=False) 
df_source4.to_csv('Urban City Trafficfault_Offset_3_V6.csv',index=False)

# %%
import pandas as pd
import glob
import os
 
path = os.getcwd()    
# merging the files
files = os.path.join(path,"*.csv")
  
# A list of all joined files is returned
files = glob.glob(files)
  
# Finally, the files are joined
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df.to_csv('Offset_Data.csv', index=False)
print(df)
# Out:
#             Time     Speed  Rotation    Position  Translation  Label
# 0       0.020005  0.000030  1.570796 -199.999999       -300.0      0
# 1       0.040010  0.120060  1.570796 -199.997598       -300.0      0
# 2       0.060015  0.240090  1.570796 -199.992795       -300.0      0
# 3       0.080020  0.360120  1.570796 -199.985590       -300.0      0
# 4       0.100025  0.480150  1.570796 -199.975985       -300.0      0
# ...          ...       ...       ...         ...          ...    ...
# 71977  79.919980  9.997528  1.570796  113.411321       -100.0      0
# 71978  79.939985  9.997579  1.570796  113.611323       -100.0      0
# 71979  79.959990  9.997628  1.570796  113.811326       -100.0      0
# 71980  79.979995  9.997677  1.570796  114.011329       -100.0      0
# 71981  80.000000  9.997724  1.570796  114.211334       -100.0      0
#
# [71982 rows x 6 columns]
